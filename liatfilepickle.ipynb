# %%
import joblib

model = joblib.load('model_rekomendasi_karir.pkl')

if hasattr(model, 'classes_'):
    print("Daftar Target / Kelas:", model.classes_)
    print("Jumlah Kelas:", len(model.classes_))
else:
    print("Model tidak memiliki atribut classes_")
# Out:
# Daftar Target / Kelas: ['Data & AI' 'Design' 'Infrastructure & Security' 'Product & Business'
#  'Software Development']
# Jumlah Kelas: 5
